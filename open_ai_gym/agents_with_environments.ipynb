# %%
import time
import gymnasium as gym

# %%
env_hum = gym.make("MountainCar-v0", render_mode = 'human')
env_rgb = env = gym.make("MountainCar-v0", render_mode = 'rgb_array')

# %%
env_rgb.action_space
# Out:
# Discrete(3)

# %%
type(env_rgb)
# Out:
# gymnasium.wrappers.common.TimeLimit

# %%
observation, _ = env_rgb.reset(seed=42)

# %%
observation2, _2 = env_hum.reset(seed=42)

# %%
for step in range(20):
    env_hum.render()
